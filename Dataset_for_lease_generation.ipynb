# %% [markdown]
# <a href="https://colab.research.google.com/github/velusrinath/GenAIPoc/blob/main/Dataset_for_lease_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing libraries

# %% [markdown]
# ## Faker

# %%
# !pip install faker -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.9 MB/s eta 0:00:00

# %% [markdown]
# # Variable declaration

# %% [markdown]
# ## Agreement types

# %%
agreement_type = {
    "rental_agreement": [
        "Residential Lease",
        "Commercial Lease",
        "Vacation Rental Agreement",
        "Roommate Agreement",
        "Lease Renewal Agreement",
        "Sublease Agreement",
        "Lease Purchase Agreement",
        "Ground Lease Agreement"
    ],
    "internet_agreement": [
        "Residential Internet Lease Agreement",
        "Commercial Internet Lease Agreement",
        "Shared Internet Lease Agreement",
        "Temporary Internet Lease Agreement",
        "Dedicated Internet Access Agreement",
        "Managed Internet Service Agreement",
        "Wholesale Internet Service Agreement"
    ],
    "vehicle_agreement": [
        "Personal Vehicle Lease Agreement",
        "Commercial Vehicle Lease Agreement",
        "Fleet Vehicle Lease Agreement",
        "Motorcycle Lease Agreement",
        "Electric Vehicle Lease Agreement"
    ]
}

# %%
agreement_type_df = {
    "rental_agreement_types": [
        "residential_lease",
        "commercial_lease",
        "vacation_rental_agreement",
        "roommate_agreement",
        "lease_renewal_agreement",
        "sublease_agreement",
        "lease_purchase_agreement",
        "ground_lease_agreement"
    ],
    "internet_agreement_types": [
        "residential_internet_lease_agreement",
        "commercial_internet_lease_agreement",
        "shared_internet_lease_agreement",
        "temporary_internet_lease_agreement",
        "dedicated_internet_access_agreement",
        "managed_internet_service_agreement",
        "wholesale_internet_service_agreement"
    ],
    "vehicle_agreement_types": [
        "personal_vehicle_lease_agreement",
        "commercial_vehicle_lease_agreement",
        "fleet_vehicle_lease_agreement",
        "motorcycle_lease_agreement",
        "electric_vehicle_lease_agreement"
    ]
}

# %% [markdown]
# ## Common Variables

# %%
# Common Variables

'''
for ease of creating training dataset,
Landlord name and Internet service provider name will be taken as Lessor name.
Rent and Internet monthly fee will be considered as monthly_lease_payment
'''
common_variables = {
    "rental_agreement" : [
        "agreement_date", "lessor_name", "lessor_address", "lessee_name", "lessee_address",
        "property_address", "lease_start_date", "lease_payment", "security_deposit",
        "number_of_days", "state"
    ],
    "internet_agreement" : [
        "lessor_name", "lessor_address", "lessee_name", "lessee_address",
        "service_address", "lease_start_date", "lease_term_months", "lease_payment", "installation_fee",
        "data_speed", "equipment_included", "service_level_agreement", "termination_policy",
        "governing_law"
    ],
    "vehicle_agreement" : [
        "lessor_name", "lessor_address", "lessee_name", "lessee_address",
        "vehicle_make", "vehicle_model", "vehicle_year", "lease_start_date",
        "lease_term_months", "lease_payment", "security_deposit",
        "mileage_limit", "maintenance_responsibility", "termination_clause",
        "governing_law"
    ]
}

# %% [markdown]
# ## Specific Variables

# %%
# Specific Variables for Each Agreement Type
specific_variables = {
    "Residential Lease" : [
        "lease_term_months"
    ],
    "Commercial Lease" : [
        "lease_term_months"
    ],
    "Vacation Rental Agreement": [
        "lease_term_months", "check-in_time", "check-out_time"
    ],
    "Roommate Agreement": [
        "lease_term_months", "equal_share_amount"
    ],
    "Lease Renewal Agreement": [
        "lease_term_months"
    ],
    "Sublease Agreement": [
        "lease_term_months"
    ],
    "Lease Purchase Agreement": [
        "lease_term_months", "purchase_price"
    ],
    "Ground Lease Agreement": [
        "land_description", "lease_term_years"
    ],
    "Residential Internet Lease Agreement": [
        "end_date", "wifi_password"
    ],
    "Commercial Internet Lease Agreement": [
        "business_name", "business_address", "static_ip_address"
    ],
    "Shared Internet Lease Agreement": [
        "main_tenant_name", "main_tenant_address", "total_fee", "fee_split"
    ],
    "Temporary Internet Lease Agreement": [
        "temporary_start_date", "temporary_end_date", "temporary_fee"
    ],
    "Dedicated Internet Access Agreement": [
        "dedicated_ip_address", "dedicated_bandwidth", "service_level",
        "uptime_guarantee"
    ],
    "Managed Internet Service Agreement": [
        "service_level_description", "network_management", "troubleshooting",
        "contract_term_years"
    ],
    "Wholesale Internet Service Agreement": [
        "wholesale_provider_name", "wholesale_service_description", "resale_terms",
        "wholesale_contract_term"
    ],
    "Personal Vehicle Lease Agreement": [
        "end_date", "monthly_insurance_fee"
    ],
    "Commercial Vehicle Lease Agreement": [
        "business_name", "business_address", "vehicle_type",
        "delivery_schedule"
    ],
    "Fleet Vehicle Lease Agreement": [
        "fleet_size", "maintenance_agreement", "replacement_policy",
        "insurance_coverage"
    ],
    "Motorcycle Lease Agreement": [
        "motorcycle_type", "safety_equipment_required", "helmet_condition",
        "motorcycle_inspection"
    ],
    "Electric Vehicle Lease Agreement": [
        "charging_station_access", "charging_cost", "charging_etiquette",
        "EV_maintenance_responsibility"
    ]
}

# %% [markdown]
# # Creating Dataframes for all lease agreement types

# %% [markdown]
# ## Retrieving fields required for agreement

# %%
# Retrieving fields required for agreement

def get_fields(agreement_type, agreement_sub_type):
    return list(set(common_variables[agreement_type] + specific_variables[agreement_sub_type]))

# %%
get_fields("vehicle_agreement", "Electric Vehicle Lease Agreement")
# Out:
# ['termination_clause',
#  'EV_maintenance_responsibility',
#  'security_deposit',
#  'lessor_name',
#  'lessee_name',
#  'lease_term_months',
#  'lessee_address',
#  'lease_payment',
#  'lease_start_date',
#  'mileage_limit',
#  'charging_cost',
#  'vehicle_model',
#  'charging_etiquette',
#  'charging_station_access',
#  'vehicle_make',
#  'vehicle_year',
#  'maintenance_responsibility',
#  'governing_law',
#  'lessor_address']

# %% [markdown]
# ## Generating Random date

# %%
from datetime import datetime, timedelta
import random

# %%
def random_date():
    start_date = datetime.now() - timedelta(days=400)
    end_date = start_date + timedelta(days=10)

    random_date = start_date + (end_date - start_date) * random.random()
    random_date = random_date.strftime("%m/%d/%Y")
    return random_date

# %% [markdown]
# ## Generating Random time

# %%
def random_time():
    return str(random.choice(range(8,20))) + ":" + random.choice(['00', '30'])

# %% [markdown]
# ## Generating Random rent amount

# %%
def random_amount():
    return random.choice(range(4000,20000, 500))

# %% [markdown]
# ## Getting all variables for a particular agreement type

# %%
def get_variables(value):
  all_variables = common_variables[value]

  for i in agreement_type[value]:
    all_variables += specific_variables[i]
  return all_variables

# %% [markdown]
# ## Variables for each agreement type

# %%
rental_variables = list(set(get_variables("rental_agreement")))
rental_variables
# Out:
# ['security_deposit',
#  'number_of_days',
#  'lessee_address',
#  'lease_payment',
#  'lease_start_date',
#  'lessor_name',
#  'lessee_name',
#  'state',
#  'agreement_date',
#  'check-out_time',
#  'land_description',
#  'lease_term_years',
#  'lease_term_months',
#  'purchase_price',
#  'property_address',
#  'lessor_address',
#  'equal_share_amount',
#  'check-in_time']

# %%
internet_variables = list(set(get_variables("internet_agreement")))
internet_variables
# Out:
# ['contract_term_years',
#  'static_ip_address',
#  'business_name',
#  'equipment_included',
#  'fee_split',
#  'uptime_guarantee',
#  'end_date',
#  'main_tenant_name',
#  'data_speed',
#  'installation_fee',
#  'wholesale_service_description',
#  'wholesale_provider_name',
#  'dedicated_ip_address',
#  'lessor_name',
#  'temporary_end_date',
#  'resale_terms',
#  'lessee_name',
#  'lease_term_months',
#  'dedicated_bandwidth',
#  'wholesale_contract_term',
#  'network_management',
#  'lessee_address',
#  'lease_payment',
#  'lease_start_date',
#  'wifi_password',
#  'service_level_description',
#  'temporary_start_date',
#  'business_address',
#  'temporary_fee',
#  'termination_policy',
#  'service_level',
#  'main_tenant_address',
#  'total_fee',
#  'troubleshooting',
#  'governing_law',
#  'lessor_address',
#  'service_level_agreement',
#  'service_address']

# %%
vehicle_variables = list(set(get_variables("vehicle_agreement")))
vehicle_variables
# Out:
# ['termination_clause',
#  'business_name',
#  'vehicle_type',
#  'end_date',
#  'insurance_coverage',
#  'EV_maintenance_responsibility',
#  'security_deposit',
#  'lessor_name',
#  'lessee_name',
#  'lease_term_months',
#  'motorcycle_type',
#  'monthly_insurance_fee',
#  'lessee_address',
#  'lease_payment',
#  'lease_start_date',
#  'mileage_limit',
#  'fleet_size',
#  'charging_cost',
#  'vehicle_model',
#  'helmet_condition',
#  'charging_etiquette',
#  'business_address',
#  'charging_station_access',
#  'motorcycle_inspection',
#  'vehicle_make',
#  'delivery_schedule',
#  'vehicle_year',
#  'replacement_policy',
#  'safety_equipment_required',
#  'maintenance_responsibility',
#  'governing_law',
#  'lessor_address',
#  'maintenance_agreement']

# %% [markdown]
# # Random data generation for Rental agreement

# %% [markdown]
# ## Functions

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

def generate_random_date(start_date, end_date):
    return fake.date_between_dates(date_start=start_date, date_end=end_date).strftime("%B %d, %Y")

def generate_land_description():
    options = [
        "The leased property consists of a single-family residential dwelling located at [Address].",
        "The property is a spacious apartment unit situated on the [Floor] floor of [Building Name].",
        "This agreement covers the lease of a [Bedroom Count]-bedroom, [Bathroom Count]-bathroom home.",
        "The leased land comprises approximately [Land Area] square feet and includes [Features].",
        "The property is a detached house with a front yard, backyard, and [Other Features].",
        "The land consists of a [Land Type] lot with access to [Amenities] nearby.",
        "This agreement pertains to a cozy cottage nestled in a [Scenic Area] setting.",
        "The leased land is part of a [Community Name] community with shared amenities like a pool and gym.",
        "The property is a [Property Type] located in a quiet and family-friendly neighborhood.",
        "This lease covers a spacious condominium unit with views of [Scenic View].",
        "The land includes a [Land Features] and is surrounded by lush greenery.",
        "The leased property is a [Property Style] with [Unique Features] that make it stand out.",
        "The land is located in the heart of [City Name], offering convenient access to [Local Attractions].",
        "This agreement pertains to an [Property Age]-year-old property with modern upgrades.",
        "The property is a historic [Historic Property Type] with preserved architectural details."
    ]
    return fake.random_element(options)

# %% [markdown]
# ## Sample

# %%
data = {
    "lessee_name": fake.name(),
    "state": fake.state(),
    "purchase_price": random.randint(100000, 1000000),
    "lease_term_months": random.randint(6, 48),
    "land_description": generate_land_description(),
    "lease_start_date": generate_random_date('-3y', '+2y'),
    "check-in_time": fake.time(pattern="%H:%M:%S", end_datetime=None),
    "equal_share_amount": random.randint(100, 1000),
    "property_address": fake.address(),
    "lease_payment": random.randint(1000, 3000),
    "agreement_date": generate_random_date('-2y', '+1y'),
    "number_of_days": random.randint(1, 30),
    "security_deposit": random.randint(1000, 5000),
    "check-out_time": fake.time(pattern="%H:%M:%S", end_datetime=None),
    "lessee_address": fake.address(),
    "lease_term_years": random.randint(1, 5),
    "lessor_address": fake.address(),
    "lessor_name": fake.name(),
}

for field, value in data.items():
    print(f"{field}: {value}")
# Out:
# lessee_name: Danielle Greene
# state: Alaska
# purchase_price: 762855
# lease_term_months: 48
# land_description: The leased property is a [Property Style] with [Unique Features] that make it stand out.
# lease_start_date: 08/27/2022
# check-in_time: 09:23 AM
# equal_share_amount: 317
# property_address: 03775 Mitchell Springs Suite 298, Port Brendaborough, Vermont
# lease_payment: 2909
# agreement_date: 08/30/2022
# number_of_days: 9
# security_deposit: 1229
# check-out_time: 09:37 AM
# lessee_address: 9911 Cox Landing, Kristinchester, Washington
# lease_term_years: 2
# lessor_address: 228 Sandra Drive, West Brittneyburgh, Tennessee
# lessor_name: Kenneth Lewis

# %% [markdown]
# # Random data generation for Internet agreement

# %% [markdown]
# ## Functions

# %%
def generate_random_ip_address():
    return fake.ipv4_public(network=False, address_class=None)

def generate_fee_split():
    return fake.random_element(elements=('50/50', '60/40', '70/30', '80/20'))

def generate_wholesale_service_description():
    options = [
        "The wholesale service includes high-speed internet access with a minimum bandwidth of [Bandwidth].",
        "This agreement covers the provision of dedicated internet connectivity for business operations.",
        "Wholesale services include data transmission, cloud access, and reliable network connectivity.",
        "The leased service provides access to a secure and redundant data network infrastructure.",
        "Wholesale internet services are designed to meet the specific bandwidth requirements of the lessee.",
        "The service includes access to a dedicated fiber-optic network with low latency and high reliability.",
        "This agreement encompasses the delivery of scalable and high-capacity internet services.",
        "Wholesale services offer 24/7 network monitoring and support for uninterrupted connectivity.",
        "The leased service is ideal for businesses requiring high-speed data transfer and minimal downtime.",
        "Service quality is guaranteed with redundancy and backup solutions in place.",
        "This agreement ensures access to a network backbone with robust security features.",
        "Wholesale services are optimized for mission-critical applications and data center connectivity.",
        "The service includes optional add-ons such as managed routers and firewall protection.",
        "The lessee will receive regular performance reports and network usage statistics.",
        "Wholesale services are designed for seamless integration with existing network infrastructure."
    ]
    return fake.random_element(options)

def generate_resale_terms():
    options = [
        "Resale terms allow the lessee to resell the internet services to third-party customers.",
        "The lessee can offer branded internet packages to their customers under the agreed resale terms.",
        "This agreement outlines pricing structures and revenue sharing arrangements for resale.",
        "Resale terms include volume-based discounts to incentivize customer acquisition.",
        "The lessee has the flexibility to set their own pricing for resale services.",
        "Resale terms specify the lessee's responsibilities in managing and supporting resale customers.",
        "The lessor provides training and resources to support successful resale operations.",
        "The lessee may request customized billing and reporting solutions for resale customers.",
        "Resale terms may be subject to periodic reviews and adjustments based on performance.",
        "The lessee can benefit from the lessor's established network infrastructure for resale.",
        "This agreement allows the lessee to expand their market reach by offering resale services.",
        "Resale terms may include marketing support and co-branding opportunities.",
        "The lessee has access to technical support and troubleshooting assistance for resale customers.",
        "Resale terms ensure that resale customers receive the same quality of service as direct customers.",
        "The lessee can tailor resale packages to meet the unique needs of their target market."
    ]
    return fake.random_element(options)

def generate_network_management():
    options = [
        "Network management services include traffic prioritization and Quality of Service (QoS) configurations.",
        "The lessor will actively monitor network performance and optimize it for efficiency.",
        "This agreement covers proactive network security measures and threat detection.",
        "Network management services ensure minimal downtime through rapid fault resolution.",
        "The lessor will provide regular network performance reports and analysis.",
        "Network management includes bandwidth allocation and optimization for peak performance.",
        "The lessee can request customized network management rules and policies.",
        "The lessor employs industry-leading tools for real-time network monitoring and management.",
        "Network management services aim to maximize network uptime and reliability.",
        "The lessor's team of experts is available 24/7 for network management support.",
        "This agreement allows for network scaling to accommodate business growth.",
        "Network management services are tailored to meet specific industry compliance requirements.",
        "The lessee can collaborate with the lessor to implement custom network management strategies.",
        "Network management services prioritize data traffic based on business-critical needs.",
        "The lessor's network management solutions are designed for optimal network performance."
    ]
    return fake.random_element(options)

def generate_service_level_description():
    options = [
        "Service levels include Service Level Agreements (SLAs) that guarantee network uptime of [Uptime Percentage]%.",
        "The lessee will receive 24/7 support and rapid response times for service-related issues.",
        "This agreement outlines service level commitments for response and resolution times.",
        "Service levels are tailored to meet the lessee's specific business requirements.",
        "The lessor guarantees a high level of network reliability and minimal service disruptions.",
        "Service levels encompass regular performance reviews and optimizations.",
        "The lessee can expect proactive monitoring and issue detection for network performance.",
        "Service level descriptions include commitments to maintain network security and data integrity.",
        "The lessor will provide detailed reports on service performance and compliance with SLAs.",
        "Service levels extend to service credits or penalties for failure to meet SLA commitments.",
        "This agreement allows the lessee to request adjustments to service levels as needed.",
        "Service levels can be customized based on the lessee's geographic coverage requirements.",
        "The lessor's team is dedicated to meeting and exceeding agreed-upon service levels.",
        "Service levels guarantee minimal packet loss and latency for optimal network performance.",
        "The lessee has access to a dedicated account manager to address service-related inquiries."
    ]
    return fake.random_element(options)

def generate_termination_policy():
    options = [
        "Termination of the agreement requires written notice with a minimum [Notice Period] days in advance.",
        "Either party can terminate the agreement for cause with a notice period of [Cause Notice Period] days.",
        "The lessee may terminate the agreement without cause with [Termination Period] days' notice.",
        "Termination may result in the lessor reclaiming any leased equipment or access devices.",
        "This agreement includes provisions for early termination fees if applicable.",
        "Termination due to breach of contract may result in legal action and penalties.",
        "The lessee is responsible for returning any leased equipment or materials upon termination.",
        "Termination will not relieve the lessee of any outstanding financial obligations.",
        "Termination may require the lessee to complete a final network transition plan.",
        "The lessor will assist with a smooth transition to a new service provider if needed.",
        "Termination policies include guidelines for data backup and retrieval.",
        "The lessee should provide notice of termination through an official written communication.",
        "Termination policies specify the date at which services and obligations will cease.",
        "Termination may include a final invoice or settlement of financial matters.",
        "The lessor may conduct a termination review meeting to ensure a seamless transition."
    ]
    return fake.random_element(options)

def generate_troubleshooting():
    options = [
        "The lessee can contact the lessor's support team 24/7 for troubleshooting assistance.",
        "Troubleshooting support includes diagnosing network issues and providing solutions.",
        "This agreement covers remote troubleshooting and on-site support if necessary.",
        "The lessor's support team is trained to resolve network issues efficiently.",
        "Troubleshooting services aim to minimize network downtime and disruptions.",
        "The lessee will receive timely updates on the progress of troubleshooting efforts.",
        "The lessor maintains a dedicated technical support hotline for immediate assistance.",
        "Troubleshooting support includes guidance on network configuration and optimization.",
        "The lessee can request a troubleshooting report for documentation and analysis.",
        "This agreement ensures that the lessor's team is readily available for troubleshooting needs.",
        "Troubleshooting efforts prioritize rapid resolution and minimal service disruption.",
        "The lessor's support team has access to advanced diagnostic tools and resources.",
        "Troubleshooting services may include hardware and software analysis and repair.",
        "The lessee will be provided with a single point of contact for troubleshooting inquiries.",
        "Troubleshooting support extends to network-related inquiries and technical guidance."
    ]
    return fake.random_element(options)

def generate_service_level_agreement():
    options = [
        "The Service Level Agreement (SLA) guarantees network uptime of [Uptime Percentage]%.",
        "This SLA outlines commitments for response and resolution times for service-related issues.",
        "The lessee will receive 24/7 support and rapid response times for service disruptions.",
        "The SLA encompasses network performance optimization and regular performance reviews.",
        "Service credits or penalties are applicable if SLA commitments are not met.",
        "This agreement ensures network reliability and minimal service disruptions.",
        "The SLA includes commitments to maintain network security and data integrity.",
        "The lessor guarantees minimal packet loss and latency for optimal network performance.",
        "The lessee has access to detailed reports on service performance and SLA compliance.",
        "The SLA can be customized based on the lessee's specific business requirements.",
        "This agreement allows the lessee to request adjustments to SLA terms as needed.",
        "The lessor's team is dedicated to meeting and exceeding SLA commitments.",
        "The lessee will receive a service level report as part of SLA compliance documentation.",
        "SLA commitments extend to service credits or penalties for failure to meet SLA terms.",
        "The lessor's technical team is trained to proactively monitor and optimize service performance."
    ]
    return fake.random_element(options)

# %% [markdown]
# ## Sample

# %%
data = {
    "contract_term_years": random.randint(1, 5),
    "static_ip_address": generate_random_ip_address(),
    "business_name": fake.company(),
    "equipment_included": fake.boolean(chance_of_getting_true=50),
    "fee_split": generate_fee_split(),
    "uptime_guarantee": random.randint(90, 99),
    "end_date": random_date(),
    "main_tenant_name": fake.name(),
    "data_speed": random.randint(10, 1000),
    "installation_fee": random.randint(100, 1000),
    "wholesale_service_description": generate_wholesale_service_description(),
    "wholesale_provider_name": fake.company(),
    "dedicated_ip_address": generate_random_ip_address(),
    "lessor_name": fake.name(),
    "temporary_end_date": random_date(),
    "resale_terms": generate_resale_terms(),
    "lessee_name": fake.name(),
    "lease_term_months": random.randint(6, 48),
    "dedicated_bandwidth": random.randint(10, 1000),
    "wholesale_contract_term": random.randint(1, 3),
    "network_management": generate_network_management(),
    "lessee_address": fake.address(),
    "lease_payment": random.randint(1000, 3000),
    "lease_start_date": random_date(),
    "wifi_password": fake.password(length=12),
    "service_level_description": generate_service_level_description(),
    "temporary_start_date": random_date(),
    "business_address": fake.address(),
    "temporary_fee": random.randint(100, 1000),
    "termination_policy": generate_termination_policy(),
    "service_level": fake.random_element(elements=("Basic", "Premium", "Enterprise")),
    "main_tenant_address": fake.address(),
    "total_fee": random.randint(1000, 5000),
    "troubleshooting": generate_troubleshooting(),
    "governing_law": fake.state(),
    "lessor_address": fake.address(),
    "service_level_agreement": generate_service_level_agreement(),
    "service_address": fake.address()
}

for field, value in data.items():
    print(f"{field}: {value}")
# Out:
# contract_term_years: 1
# static_ip_address: 63.245.208.141
# business_name: Natalie Martinez
# equipment_included: True
# fee_split: 18
# uptime_guarantee: 96
# end_date: 09/04/2022
# main_tenant_name: Melanie Lane
# data_speed: 603
# installation_fee: 326
# wholesale_service_description: The service includes access to a dedicated fiber-optic network with low latency and high reliability.
# wholesale_provider_name: Christopher Taylor DDS
# dedicated_ip_address: 116.167.204.130
# lessor_name: Michael Ward
# temporary_end_date: 09/03/2022
# resale_terms: Resale terms include volume-based discounts to incentivize customer acquisition.
# lessee_name: Susan Thomas
# lease_term_months: 37
# dedicated_bandwidth: 720
# wholesale_contract_term: 2
# network_management: This agreement allows for network scaling to accommodate business growth.
# lessee_address: 101 Teresa Corners Apt. 178
# lease_payment: 1398
# lease_start_date: 09/01/2022
# wifi_password: &6PLKoa1F3
# ...

# %% [markdown]
# # Random data generation for Vehicle agreement

# %% [markdown]
# ## Fuctions

# %%
def generate_vehicle_make():
    return fake.word(ext_word_list=["Toyota", "Ford", "Honda", "Audi", "BMW", "Nissan", "Tata"])

def generate_vehicle_model():
    return fake.word(ext_word_list=["Sedan", "SUV", "Truck"])

def generate_ev_maintenance_responsibility():
    options = [
        "The lessee is responsible for routine maintenance of the electric vehicle, including tire rotations and battery checks.",
        "Maintenance and repairs for the electric vehicle are covered by the lessor as part of this agreement.",
        "The lessee is responsible for maintaining the electric vehicle's charging equipment and reporting any issues promptly.",
        "Routine maintenance costs for the electric vehicle will be shared between the lessor and lessee.",
        "The lessor provides a comprehensive maintenance package for the electric vehicle, including regular check-ups and repairs.",
        "Both parties agree to adhere to the electric vehicle manufacturer's recommended maintenance schedule.",
        "Maintenance and servicing for the electric vehicle will be performed by authorized service centers.",
        "The lessee is responsible for keeping maintenance records and sharing them with the lessor as needed.",
        "Maintenance of the electric vehicle's battery is covered by a separate warranty.",
        "The lessor will arrange for periodic maintenance appointments with the lessee's consent.",
        "Emergency maintenance services for the electric vehicle are available 24/7.",
        "The lessee is responsible for notifying the lessor of any maintenance or repair needs promptly.",
        "Scheduled maintenance for the electric vehicle will be coordinated to minimize disruption to the lessee.",
        "The lessor provides access to a network of certified mechanics for maintenance and repairs.",
        "Maintenance tasks, such as software updates, will be performed remotely by the lessor."
    ]
    return fake.random_element(options)

def generate_termination_clause():
    options = [
        "This agreement can be terminated with a 30-day notice by either party.",
        "Termination of this agreement requires written notice and a minimum notice period of 60 days.",
        "Early termination of the lease may result in additional fees as specified in the termination clause.",
        "Termination is allowed without penalty in case of a total loss or destruction of the vehicle.",
        "The lessee has the option to terminate the lease after a specified initial term.",
        "Termination due to breach of contract will be subject to legal action.",
        "The lessor reserves the right to terminate the agreement for non-payment of fees.",
        "Termination due to vehicle misuse or unauthorized modifications may result in penalties.",
        "Either party may terminate this agreement if the vehicle becomes unsafe to operate.",
        "Termination can be requested for reasons of financial hardship with supporting documentation.",
        "The lessor may terminate the agreement if the lessee fails to maintain required insurance coverage.",
        "Termination due to a change in the lessee's circumstances may be subject to negotiation.",
        "The lessee may terminate the agreement if the vehicle experiences recurring mechanical issues.",
        "Termination can be requested for medical reasons that prevent vehicle use with appropriate documentation.",
        "The lessee may terminate the agreement if the vehicle is no longer suitable for their needs."
    ]
    return fake.random_element(options)

def generate_charging_etiquette():
    options = [
        "When using public charging stations, please be considerate of other users and follow posted rules.",
        "Do not leave the vehicle plugged in longer than necessary to allow others access to the charging station.",
        "In residential settings, please coordinate charging schedules with other tenants to avoid conflicts.",
        "Always unplug the vehicle promptly after charging to free up the charging station for others.",
        "Be mindful of peak charging times and try to avoid overloading the electrical grid.",
        "Avoid parking in designated charging spots if your vehicle does not require charging.",
        "Respect posted charging rates and fees at public charging stations.",
        "Consider charging your vehicle during off-peak hours to reduce strain on the electrical grid.",
        "Share charging station access codes and information with other authorized users only.",
        "Notify the lessor immediately if you encounter any issues with the charging equipment.",
        "Always park your vehicle within the designated charging area when using a public station.",
        "Avoid charging station hogging; move your vehicle once it's fully charged to free up the station.",
        "Respect any time limits or restrictions imposed on charging stations.",
        "Do not use unauthorized charging adapters or equipment to avoid potential damage.",
        "Report any vandalism or misuse of charging stations to the relevant authorities."
    ]
    return fake.random_element(options)

def generate_delivery_schedule():
    options = [
        "Vehicle deliveries will be scheduled based on availability and may require advance notice.",
        "Delivery times will be mutually agreed upon between the lessor and lessee.",
        "Delivery of the vehicle will be made to the lessee's specified address on the agreed-upon date.",
        "The lessor will arrange for vehicle delivery to a designated pickup point for the lessee's convenience.",
        "Delivery may be subject to delays due to unforeseen circumstances or logistical challenges.",
        "The lessee can request a specific delivery date and time, subject to availability.",
        "The lessor will provide a delivery confirmation and tracking information once the vehicle is dispatched.",
        "Delivery personnel will provide an orientation on vehicle features and operation upon delivery.",
        "The lessee should inspect the vehicle upon delivery and report any issues immediately.",
        "In case of delivery delays, the lessor will provide updates and revised delivery times.",
        "The lessor may charge a fee for delivery services based on distance and complexity.",
        "The lessee can request a change in the delivery address with prior notice to the lessor.",
        "Special delivery arrangements can be made for lessees with unique requirements.",
        "The lessor will ensure the vehicle is delivered in clean and fully operational condition.",
        "Delivery appointments will be confirmed in advance to ensure a smooth process."
    ]
    return fake.random_element(options)

def generate_replacement_policy():
    options = [
        "In the event of vehicle damage, replacement parts will be sourced and replaced as needed.",
        "A replacement vehicle will be provided to the lessee in case of extended repair periods.",
        "Replacement of damaged or malfunctioning components will be performed according to manufacturer specifications.",
        "The lessor maintains a stock of commonly needed replacement parts for quick repairs.",
        "The lessee is responsible for reporting damage promptly to initiate the replacement process.",
        "Replacement vehicles will be of similar make and model when available.",
        "In case of a total loss, the lessor will arrange for a replacement vehicle.",
        "Replacement vehicles will be provided at no additional cost to the lessee.",
        "The lessor will provide a timeline for replacement part availability and installation.",
        "A replacement vehicle will be delivered to the lessee's specified location for convenience.",
        "The lessee should promptly return the replacement vehicle once their original vehicle is repaired.",
        "Replacement parts and vehicles will meet safety and quality standards.",
        "The lessor will coordinate the replacement process to minimize lessee inconvenience.",
        "In the event of non-repairable damage, the lessor will provide a suitable replacement option.",
        "The lessee may request additional information on the replacement process at any time."
    ]
    return fake.random_element(options)

def generate_safety_equipment_required():
    options = [
        "The lessee is required to wear appropriate safety gear, including helmets and protective clothing, when operating the vehicle.",
        "Safety equipment such as seatbelts and helmets must be worn at all times while using the vehicle.",
        "The lessee is responsible for providing and maintaining safety equipment as required by law.",
        "Safety equipment, including airbags and anti-lock brakes, is installed and functional in the vehicle.",
        "The lessee should regularly inspect safety equipment and report any issues for prompt repair or replacement.",
        "Proper use of safety equipment is essential for the lessee's safety and the safety of others on the road.",
        "The lessor provides guidelines on the type and specifications of safety equipment required.",
        "Any damage or malfunction of safety equipment should be reported immediately to the lessor.",
        "Failure to use required safety equipment may result in penalties and lease termination.",
        "The lessee should educate passengers on the importance of safety equipment and their proper use.",
        "Safety equipment usage is mandatory during test drives and vehicle demonstrations.",
        "The lessee is responsible for complying with all safety regulations and laws while using the vehicle.",
        "Safety equipment includes reflective vests and warning triangles for roadside emergencies.",
        "Safety equipment requirements may vary depending on the vehicle type and local regulations.",
        "The lessor will provide guidance on the appropriate safety equipment for specific use cases."
    ]
    return fake.random_element(options)

def generate_maintenance_responsibility():
    options = [
        "Routine maintenance and minor repairs are the responsibility of the lessee as specified in the agreement.",
        "Maintenance and repair costs are covered by the lessor, excluding damage due to lessee negligence.",
        "The lessee is responsible for maintaining the vehicle's cleanliness and reporting any issues promptly.",
        "Scheduled maintenance services will be provided by authorized service centers at no cost to the lessee.",
        "Maintenance tasks, such as oil changes and filter replacements, should be performed at regular intervals.",
        "The lessee should follow manufacturer-recommended maintenance schedules for optimal vehicle performance.",
        "Maintenance and service appointments can be scheduled online or through the lessor's service department.",
        "The lessor provides access to a network of certified mechanics for maintenance and repairs.",
        "Emergency maintenance services are available 24/7 for unexpected breakdowns or issues.",
        "The lessee is encouraged to report any unusual vehicle behavior or noises for prompt inspection.",
        "Maintenance records should be retained by the lessee and shared with the lessor as needed.",
        "The lessor may conduct periodic maintenance checks to ensure the vehicle's proper condition.",
        "Maintenance responsibilities may be adjusted based on the lessee's usage and mileage.",
        "The lessee should adhere to all maintenance guidelines outlined in the agreement.",
        "Maintenance responsibilities may vary based on the vehicle type and model."
    ]
    return fake.random_element(options)

def generate_maintenance_agreement():
    options = [
        "A separate maintenance agreement outlines the specific maintenance services provided by the lessor.",
        "Maintenance services include regular oil changes, tire rotations, and vehicle inspections.",
        "The lessee is responsible for following the maintenance schedule outlined in the agreement.",
        "Maintenance agreements cover both routine services and unexpected repairs as needed.",
        "The lessor offers flexible maintenance packages tailored to the lessee's needs and preferences.",
        "Maintenance appointments can be scheduled at the lessee's convenience through the lessor's service department.",
        "In case of breakdowns or emergencies, the lessor provides expedited maintenance services.",
        "Maintenance agreements may include additional services such as roadside assistance and towing.",
        "The lessee can choose from various maintenance plans with different levels of coverage.",
        "Maintenance agreements are designed to ensure the vehicle's reliability and longevity.",
        "The lessor may offer discounted maintenance packages for long-term lease agreements.",
        "The lessee can contact the lessor's maintenance team for any questions or concerns.",
        "Maintenance agreements may be transferable to new lessees in case of vehicle resale.",
        "The lessor's service department is staffed with experienced technicians trained to work on the leased vehicles.",
        "Detailed terms and conditions of the maintenance agreement are provided in a separate document."
    ]
    return fake.random_element(options)

def generate_insurance_coverage():
    options = [
        "Liability coverage includes protection for third-party injuries and property damage.",
        "Comprehensive coverage provides protection against non-collision incidents such as theft, vandalism, and natural disasters.",
        "Collision coverage covers damage to your vehicle in the event of an accident with another vehicle or object.",
        "Full coverage typically includes liability, comprehensive, and collision coverage for comprehensive protection.",
        "Minimum coverage includes the basic liability required by law but may not cover all types of accidents.",
        "Personal injury protection (PIP) coverage provides medical and related expenses coverage for the lessee.",
        "Uninsured/underinsured motorist coverage offers protection in case of accidents involving drivers with insufficient insurance.",
        "Rental car coverage provides reimbursement for renting a replacement vehicle while your leased vehicle is being repaired.",
        "Gap insurance covers the difference between the leased vehicle's current value and the remaining lease balance in case of a total loss.",
        "Medical payments coverage offers additional medical expense coverage for injuries sustained in a vehicle accident.",
        "Towing and labor coverage provides reimbursement for emergency services such as towing and roadside assistance.",
        "Custom equipment coverage covers aftermarket additions and modifications to the leased vehicle.",
        "Special perils coverage extends coverage to include specific named perils, such as floods or earthquakes.",
        "Rental reimbursement coverage offers reimbursement for renting a vehicle when your leased vehicle is temporarily unavailable.",
        "Limited use coverage may be available for vehicles with low mileage or limited use requirements."
    ]
    return fake.random_element(options)

def generate_motorcycle_inspection():
    options = [
        "Regular motorcycle inspections will be conducted by the lessor to ensure safety and compliance.",
        "The lessee is responsible for performing routine safety checks on the motorcycle.",
        "Periodic motorcycle inspections will be scheduled to assess the condition and safety of the vehicle.",
        "Safety inspections will include checks on brakes, lights, tires, and other critical components.",
        "The lessor will provide a checklist for the lessee to follow during motorcycle inspections.",
        "Any identified safety issues during inspections should be promptly reported for repair.",
        "Inspections may be scheduled at specific intervals or before long trips for added safety.",
        "Safety inspections are essential for maintaining the motorcycle's optimal performance and reliability.",
        "Inspection records will be kept for reference and verification of maintenance compliance.",
        "The lessor may conduct surprise inspections to ensure ongoing safety and compliance.",
        "The lessee is encouraged to develop a routine inspection schedule to ensure the motorcycle's safety.",
        "In case of safety recalls, the lessor will promptly address and resolve the issue.",
        "Regular motorcycle inspections are a proactive approach to preventing potential accidents.",
        "The lessee should receive an inspection report after each scheduled inspection.",
        "Motorcycle inspections will be conducted by certified mechanics to ensure accuracy."
    ]
    return fake.random_element(options)

def generate_charging_station_access():
    options = [
        "The lessee will have access to a network of charging stations located throughout the region.",
        "Charging station access cards will be provided to the lessee for convenient use.",
        "Access to charging stations will be available 24/7 for lessee convenience.",
        "Charging stations can be easily located and accessed using a dedicated mobile app.",
        "Charging station access will include both public charging points and private charging facilities.",
        "The lessee will receive instructions on how to use charging stations upon lease agreement signing.",
        "Charging station access is provided as part of the lease package at no additional cost.",
        "The lessor will provide assistance in finding and using charging stations, if needed.",
        "Access to a charging station reservation system will be available for lessee convenience.",
        "Charging station access will include fast-charging options for quick battery replenishment.",
        "Charging station locations are strategically chosen for easy access and convenience.",
        "The lessee will be informed of any charging station network updates or expansions.",
        "Charging stations are equipped with user-friendly interfaces for hassle-free charging.",
        "Charging station access will be extended to accommodate long trips and travel needs.",
        "The lessor offers dedicated customer support for any charging station access inquiries."
    ]
    return fake.random_element(options)

# %% [markdown]
# ## Sample

# %%
data = {
    "termination_clause": generate_termination_clause(),
    "business_name": fake.company(),
    "vehicle_type": fake.random_element(elements=('Sedan', 'SUV', 'Truck', 'Motorcycle')),
    "end_date": generate_random_date('today', '+1y'),
    "insurance_coverage": generate_insurance_coverage(),
    "EV_maintenance_responsibility": generate_ev_maintenance_responsibility(),
    "security_deposit": random.randint(1000, 5000),
    "lessor_name": fake.name(),
    "lessee_name": fake.name(),
    "lease_term_months": random.randint(6, 36),
    "motorcycle_type": fake.random_element(elements=("Sport", "Cruiser", "Touring")),
    "monthly_insurance_fee": random.randint(50, 500),
    "lessee_address": fake.address(),
    "lease_payment": random.randint(100, 1000),
    "lease_start_date": generate_random_date('-1y', '+1y'),
    "mileage_limit": random.randint(30, 50),
    "fleet_size": random.randint(1, 100),
    "charging_cost": random.randint(10, 50),
    "vehicle_model": generate_vehicle_model(),
    "helmet_condition": fake.random_element(elements=("Good", "Fair", "Poor")),
    "charging_etiquette": generate_charging_etiquette(),
    "business_address": fake.address(),
    "charging_station_access": generate_charging_station_access(),
    "motorcycle_inspection": generate_motorcycle_inspection(),
    "vehicle_make": generate_vehicle_make(),
    "delivery_schedule": generate_delivery_schedule(),
    "vehicle_year": random.randint(2010, 2023),
    "replacement_policy": generate_replacement_policy(),
    "safety_equipment_required": generate_safety_equipment_required(),
    "maintenance_responsibility": generate_maintenance_responsibility(),
    "governing_law": fake.state(),
    "lessor_address": fake.address(),
    "maintenance_agreement": generate_maintenance_agreement()}

for field, value in data.items():
    print(f"{field}: {value}")
# Out:
# termination_clause: Termination due to a change in the lessee's circumstances may be subject to negotiation.
# business_name: Julie Wade
# vehicle_type: Truck
# end_date: 08/31/2022
# insurance_coverage: Rental car coverage provides reimbursement for renting a replacement vehicle while your leased vehicle is being repaired.
# EV_maintenance_responsibility: The lessor will arrange for periodic maintenance appointments with the lessee's consent.
# security_deposit: 1263
# lessor_name: Brittany Mcguire
# lessee_name: Gina Smith
# lease_term_months: 53
# motorcycle_type: Sport
# monthly_insurance_fee: 66
# lessee_address: 33241 Chad Rapids
# lease_payment: 967
# lease_start_date: 09/05/2022
# mileage_limit: 5078
# fleet_size: 68
# charging_cost: 30
# vehicle_model: Sedan
# helmet_condition: Fair
# charging_etiquette: Avoid parking in designated charging spots if your vehicle does not require charging.
# business_address: 082 Walker Harbor
# ...

# %% [markdown]
# # Creating Rental dataframe

# %%
rental_schema = {
    'security_deposit': [],
    'number_of_days': [],
    'lessee_address': [],
    'lease_payment': [],
    'lease_start_date': [],
    'lessor_name': [],
    'lessee_name': [],
    'state': [],
    'agreement_date': [],
    'check-out_time': [],
    'land_description': [],
    'lease_term_years': [],
    'lease_term_months': [],
    'purchase_price': [],
    'property_address': [],
    'lessor_address': [],
    'equal_share_amount': [],
    'check-in_time': []
}

for _ in range(1000):
    rental_schema['security_deposit'].append(random.randint(500, 5000))
    rental_schema['number_of_days'].append(random.randint(1, 365))
    rental_schema['lessee_address'].append(fake.address())
    rental_schema['lease_payment'].append(random.randint(1000, 5000))
    rental_schema['lease_start_date'].append(generate_random_date('-2y','+2y'))
    rental_schema['lessor_name'].append(fake.name())
    rental_schema['lessee_name'].append(fake.name())
    rental_schema['state'].append(fake.state())
    rental_schema['agreement_date'].append(generate_random_date('-3y', '+1y'))
    rental_schema['check-out_time'].append(fake.time(pattern="%H:%M:%S", end_datetime=None))
    rental_schema['land_description'].append(generate_land_description())
    rental_schema['lease_term_years'].append(random.randint(1, 5))
    rental_schema['lease_term_months'].append(random.randint(6, 36))
    rental_schema['purchase_price'].append(random.randint(100000, 1000000))
    rental_schema['property_address'].append(fake.address())
    rental_schema['lessor_address'].append(fake.address())
    rental_schema['equal_share_amount'].append(random.randint(100, 1000))
    rental_schema['check-in_time'].append(fake.time(pattern="%H:%M:%S", end_datetime=None))

rental_df = pd.DataFrame(rental_schema)

rental_df.head()
# Out:
#    security_deposit  number_of_days  \
# 0              4307              96
# 1              3695              60
# 2              3176             193
# 3               989             228
# 4              1913              49
#
#                                       lessee_address  lease_payment  \
# 0  7282 Melissa Hollow Apt. 575\nHillborough, FM ...           2214
# 1            131 Jones Spur\nAlexandraland, WA 49889           2451
# 2                   Unit 7084 Box 0231\nDPO AE 41157           4247
# 3         7533 Davis Streets\nKaylaborough, PR 34092           2199
# 4                            USS Tyler\nFPO AA 36713           2983
#
#   lease_start_date         lessor_name        lessee_name          state  \
# 0       2023-06-22  Samantha Duarte MD        Tommy Perez        Georgia
# 1       2023-12-26        Rachel Davis        Gary Miller  New Hampshire
# 2       2024-04-20         Lauren Long  Brianna Marks DVM           Utah
# ...

# %% [markdown]
# # Creating Internet dataframe

# %%
internet_schema = {
    'contract_term_years': [],
    'static_ip_address': [],
    'business_name': [],
    'equipment_included': [],
    'fee_split': [],
    'uptime_guarantee': [],
    'end_date': [],
    'main_tenant_name': [],
    'data_speed': [],
    'installation_fee': [],
    'wholesale_service_description': [],
    'wholesale_provider_name': [],
    'dedicated_ip_address': [],
    'lessor_name': [],
    'temporary_end_date': [],
    'resale_terms': [],
    'lessee_name': [],
    'lease_term_months': [],
    'dedicated_bandwidth': [],
    'wholesale_contract_term': [],
    'network_management': [],
    'lessee_address': [],
    'lease_payment': [],
    'lease_start_date': [],
    'wifi_password': [],
    'service_level_description': [],
    'temporary_start_date': [],
    'business_address': [],
    'temporary_fee': [],
    'termination_policy': [],
    'service_level': [],
    'main_tenant_address': [],
    'total_fee': [],
    'troubleshooting': [],
    'governing_law': [],
    'lessor_address': [],
    'service_level_agreement': [],
    'service_address': []
}

for _ in range(1000):
    internet_schema['contract_term_years'].append(random.randint(1, 5))
    internet_schema['static_ip_address'].append(generate_random_ip_address())
    internet_schema['business_name'].append(fake.company())
    internet_schema['equipment_included'].append(fake.boolean(chance_of_getting_true=50))
    internet_schema['fee_split'].append(generate_fee_split())
    internet_schema['uptime_guarantee'].append(random.randint(90, 99))
    internet_schema['end_date'].append(fake.date_between(start_date='today', end_date='+1y'))
    internet_schema['main_tenant_name'].append(fake.name())
    internet_schema['data_speed'].append(random.randint(10, 1000))
    internet_schema['installation_fee'].append(random.randint(100, 1000))
    internet_schema['wholesale_service_description'].append(generate_wholesale_service_description())
    internet_schema['wholesale_provider_name'].append(fake.company())
    internet_schema['dedicated_ip_address'].append(generate_random_ip_address())
    internet_schema['lessor_name'].append(fake.name())
    internet_schema['temporary_end_date'].append(generate_random_date('+1d', '+30d'))
    internet_schema['resale_terms'].append(generate_resale_terms())
    internet_schema['lessee_name'].append(fake.name())
    internet_schema['lease_term_months'].append(random.randint(6, 36))
    internet_schema['dedicated_bandwidth'].append(random.randint(10, 1000))
    internet_schema['wholesale_contract_term'].append(fake.random_element(elements=('1 year', '2 years', '3 years', '5 years', '10 years', '15 years')))
    internet_schema['network_management'].append(generate_network_management())
    internet_schema['lessee_address'].append(fake.address())
    internet_schema['lease_payment'].append(random.randint(500, 5000))
    internet_schema['lease_start_date'].append(generate_random_date('-1y', '+1y'))
    internet_schema['wifi_password'].append(fake.password(length=12))
    internet_schema['service_level_description'].append(generate_service_level_description())
    internet_schema['temporary_start_date'].append(generate_random_date('+1d', '+30d'))
    internet_schema['business_address'].append(fake.address())
    internet_schema['temporary_fee'].append(random.randint(50, 500))
    internet_schema['termination_policy'].append(generate_termination_policy())
    internet_schema['service_level'].append(fake.random_element(elements=('Standard', 'Premium', 'Enterprise')))
    internet_schema['main_tenant_address'].append(fake.address())
    internet_schema['total_fee'].append(random.randint(1000, 10000))
    internet_schema['troubleshooting'].append(generate_troubleshooting())
    internet_schema['governing_law'].append(fake.state())
    internet_schema['lessor_address'].append(fake.address())
    internet_schema['service_level_agreement'].append(generate_service_level_agreement())
    internet_schema['service_address'].append(fake.address())

internet_df = pd.DataFrame(internet_schema)

internet_df.head()
# Out:
#    contract_term_years static_ip_address    business_name  equipment_included  \
# 0                    1    146.221.212.16       Morris Ltd                True
# 1                    3      2.117.13.124       Smith-Webb                True
# 2                    3    202.77.164.151        Flynn Inc               False
# 3                    5    44.252.253.139  Delgado-Edwards                True
# 4                    2      26.95.64.244    Wong and Sons               False
#
#   fee_split uptime_guarantee    end_date    main_tenant_name  data_speed  \
# 0     60/40            99.9%  2024-03-06      Vanessa Savage          29
# 1     50/50              99%  2023-12-15        James Garcia         529
# 2     70/30            99.9%  2023-11-19  Christine Davidson         575
# 3     60/40            99.9%  2024-02-23       Stephen Velez         481
# 4     70/30            99.9%  2023-10-30           Amy Perez         974
#
#    installation_fee  ... temporary_fee  \
# ...

# %% [markdown]
# # Create Vehicle dataframe

# %%
vehicle_schema = {
    'termination_clause': [],
    'business_name': [],
    'vehicle_type': [],
    'end_date': [],
    'insurance_coverage': [],
    'EV_maintenance_responsibility': [],
    'security_deposit': [],
    'lessor_name': [],
    'lessee_name': [],
    'lease_term_months': [],
    'motorcycle_type': [],
    'monthly_insurance_fee': [],
    'lessee_address': [],
    'lease_payment': [],
    'lease_start_date': [],
    'mileage_limit': [],
    'fleet_size': [],
    'charging_cost': [],
    'vehicle_model': [],
    'helmet_condition': [],
    'charging_etiquette': [],
    'business_address': [],
    'charging_station_access': [],
    'motorcycle_inspection': [],
    'vehicle_make': [],
    'delivery_schedule': [],
    'vehicle_year': [],
    'replacement_policy': [],
    'safety_equipment_required': [],
    'maintenance_responsibility': [],
    'governing_law': [],
    'lessor_address': [],
    'maintenance_agreement': []
}

for _ in range(1000):
    vehicle_schema['termination_clause'].append(generate_termination_clause())
    vehicle_schema['business_name'].append(fake.company())
    vehicle_schema['vehicle_type'].append(fake.random_element(elements=('Sedan', 'SUV', 'Truck', 'Motorcycle')))
    vehicle_schema['end_date'].append(generate_random_date('today', '+1y'))
    vehicle_schema['insurance_coverage'].append(generate_insurance_coverage())
    vehicle_schema['EV_maintenance_responsibility'].append(generate_ev_maintenance_responsibility())
    vehicle_schema['security_deposit'].append(random.randint(1000, 5000))
    vehicle_schema['lessor_name'].append(fake.name())
    vehicle_schema['lessee_name'].append(fake.name())
    vehicle_schema['lease_term_months'].append(random.randint(6, 36))
    vehicle_schema['motorcycle_type'].append(fake.random_element(elements=("Sport", "Cruiser", "Touring")))
    vehicle_schema['monthly_insurance_fee'].append(random.randint(50, 500))
    vehicle_schema['lessee_address'].append(fake.address())
    vehicle_schema['lease_payment'].append(random.randint(100, 1000))
    vehicle_schema['lease_start_date'].append(generate_random_date('-1y', '+1y'))
    vehicle_schema['mileage_limit'].append(random.randint(30, 50))
    vehicle_schema['fleet_size'].append(random.randint(1, 100))
    vehicle_schema['charging_cost'].append(random.randint(10, 50))
    vehicle_schema['vehicle_model'].append(generate_vehicle_model())
    vehicle_schema['helmet_condition'].append(fake.random_element(elements=("Good", "Fair", "Poor")))
    vehicle_schema['charging_etiquette'].append(generate_charging_etiquette())
    vehicle_schema['business_address'].append(fake.address())
    vehicle_schema['charging_station_access'].append(fake.random_element(elements=('Yes', 'No')))
    vehicle_schema['motorcycle_inspection'].append(generate_motorcycle_inspection())
    vehicle_schema['vehicle_make'].append(generate_vehicle_make())
    vehicle_schema['delivery_schedule'].append(generate_delivery_schedule())
    vehicle_schema['vehicle_year'].append(random.randint(2010, 2023))
    vehicle_schema['replacement_policy'].append(generate_replacement_policy())
    vehicle_schema['safety_equipment_required'].append(fake.random_element(elements=('Helmet', 'Gloves', 'Jacket')))
    vehicle_schema['maintenance_responsibility'].append(generate_maintenance_responsibility())
    vehicle_schema['governing_law'].append(fake.state())
    vehicle_schema['lessor_address'].append(fake.address())
    vehicle_schema['maintenance_agreement'].append(generate_maintenance_agreement())

vehicle_df = pd.DataFrame(vehicle_schema)

vehicle_df.head()
# Out:
#                                   termination_clause  \
# 0  The lessee may terminate the agreement if the ...
# 1  Early termination of the lease may result in a...
# 2  Either party may terminate this agreement if t...
# 3  Termination due to vehicle misuse or unauthori...
# 4  Termination due to a change in the lessee's ci...
#
#                   business_name vehicle_type    end_date insurance_coverage  \
# 0                    Soto Group        Sedan  2024-06-11      Full Coverage
# 1                    Morris PLC        Truck  2024-03-26               None
# 2  Graham, Roberts and Gonzalez        Truck  2024-06-11      Full Coverage
# 3                   Barker-Hull        Truck  2024-08-12               None
# 4                      Ward LLC   Motorcycle  2024-02-14               None
#
#                        EV_maintenance_responsibility  security_deposit  \
# 0  Maintenance tasks, such as software updates, w...               645
# ...
